# %%
# %pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('supermarket_sales.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Member  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22       8.0  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31       7.0  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                   float64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0      2019-01-05
# 1      2019-03-08
# 2      2019-03-03
# 3      2019-01-27
# 4      2019-02-08
#           ...
# 997    2019-02-09
# 998    2019-02-22
# 999    2019-02-18
# 1000   2019-03-10
# 1001   2019-02-26
# Name: Date, Length: 1002, dtype: datetime64[ns]

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated()==True]
# Out:
#        Invoice ID Branch      City Customer type Gender  \
# 1000  745-74-0715      A    Yangon        Normal   Male
# 1001  518-71-6847      B  Mandalay        Member   Male
#
#                 Product line  Unit price  Quantity  Tax 5%    Total  \
# 1000  Electronic accessories       58.03       2.0   5.803  121.863
# 1001      Food and beverages       26.60       6.0   7.980  167.580
#
#            Date   Time  Payment    cogs  gross margin percentage  \
# 1000 2019-03-10  20:46  Ewallet  116.06                 4.761905
# 1001 2019-02-26  15:10  Ewallet  159.60                 4.761905
#
#       gross income  Rating
# 1000         5.803     8.8
# 1001         7.980     4.9

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()/len(df)
# Out:
# Invoice ID                 0.000
# Branch                     0.000
# City                       0.000
# Customer type              0.008
# Gender                     0.000
# Product line               0.000
# Unit price                 0.000
# Quantity                   0.008
# Tax 5%                     0.000
# Total                      0.000
# Date                       0.000
# Time                       0.000
# Payment                    0.000
# cogs                       0.000
# gross margin percentage    0.000
# gross income               0.000
# Rating                     0.000
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.fillna(df.mean(),inplace=True)
# Out:
# <ipython-input-31-faa1320c28a3>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# <ipython-input-31-faa1320c28a3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(),inplace=True)

# %%
df.isna().sum()/len(df)
# Out:
# Invoice ID                 0.000
# Branch                     0.000
# City                       0.000
# Customer type              0.008
# Gender                     0.000
# Product line               0.000
# Unit price                 0.000
# Quantity                   0.000
# Tax 5%                     0.000
# Total                      0.000
# Date                       0.000
# Time                       0.000
# Payment                    0.000
# cogs                       0.000
# gross margin percentage    0.000
# gross income               0.000
# Rating                     0.000
# dtype: float64

# %%
df.fillna(df.mode().iloc[0],inplace=True)
# Out:
# <ipython-input-33-a295f8d898ac>:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.fillna(df.mode().iloc[0],inplace=True)

# %%
df.isna().sum()/len(df)
# Out:
# Invoice ID                 0.0
# Branch                     0.0
# City                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Which branch sells more

# %%
sns.countplot(data=df,x='Branch')
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# Which payment method is used the most

# %%
sns.countplot(data=df,x='Payment')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Unit price'}>,
#         <AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'Tax 5%'}>],
#        [<AxesSubplot:title={'center':'Total'}>,
#         <AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'cogs'}>],
#        [<AxesSubplot:title={'center':'gross margin percentage'}>,
#         <AxesSubplot:title={'center':'gross income'}>,
#         <AxesSubplot:title={'center':'Rating'}>]], dtype=object)

# %% [markdown]
# Which type of product is sold the most

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x='Product line',
              order=df['Product line'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %% [markdown]
# Who spends the most

# %%
sns.boxplot(x=df['Gender'],y=df['gross income'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %%
sns.heatmap(np.round(df.corr(numeric_only = True),2),annot=True)
# Out:
# <AxesSubplot:>
